# %% [markdown]
# # DataScribe 0.1

# %%
#Dependencies

import numpy as np
import datetime
from math import *
import operator
import statistics
import random

# %%
#Modules
from process_csv import Process_CSV, DataFrame_2D
from grammar import Constructor, parse
from datascribe import GUI

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ### Process CSV

# %%
data = Process_CSV('stocks.csv')
data.labels_row = False
data.set_axis("x",1,'datetime','%b %d %Y')
data.set_axis("y",2,'float', None)
data.variable_col = 0

# %% [markdown]
# ### Data Frame

# %%
data_frame = data.transform()
AAPL = data_frame[0]
AMZN = data_frame[1]
GOOG = data_frame[2]
IBM = data_frame[3]
MSFT = data_frame[4]

def display(frame):
    DataFrame_2D(frame[0],frame[1],None).visualize(True)
    print("\n\n".join(Constructor(DataFrame_2D(frame[0],frame[1],None)).get_string))

# %%
display(GOOG)
# Out:
# Between  Aug 2004 & Nov 2007 , there was a steep growth of
# 576%. During this period, GOOG incremented slightly to a value of
# $432.66 by Jan 2006, and further continued to grow to a value of
# $707.0 by Oct 2007.
#
# However, from  Nov 2007 to Mar 2010 , It marginally decreased
# by 19%. During this period, It declined to a value of $292.96 by Nov
# 2008 but immediately rose back to a value of $619.98 by Dec 2009.

# %%
GUI(GOOG)

# %%
display(AMZN)
# Out:
# AMZN depleted non-uniformly from $64 to $38 between  2000 & 2006
# , after decreasing to a minimum of $5.97 in Sep 2001.
#
# On the contrary, there was a increase from $38 to $128 during the
# period,  2006 - 2010 , although It depleted to $42.7 in Nov
# 2008.

# %%
GUI(AMZN)

# %%
display(AAPL)
# Out:
# There was a slight increase from $25 to $38 between  2000 & 2005
# .
#
# Between  2005 & 2010 , AAPL sharply rose by 480%. During this
# period, AAPL increased slightly to a value of $91.66 by Nov 2006, and
# further continued to rise to $210.73 by Dec 2009, except for a sudden
# fall to $85.35 in Dec 2008.

# %%
GUI(AAPL)

# %%
display(MSFT)
# Out:
# Between  2000 & 2003 , MSFT declined slightly by 49%. During
# this period, MSFT fell slightly to a value of $17.65 by Dec 2000, and
# further continued to fall to $17.79 by Sep 2002.
#
# On the contrary, between  2003 & 2010 , It rose from $20 to
# $28, despite depleting to $15.81 in Feb 2009.

# %%
GUI(MSFT)

# %%
display(IBM)
# Out:
# From  2000 to 2003 , there was a slight decrease of 15%.
# During this period, IBM depleted to $53.01 by Sep 2002 but immediately
# incremented back to $83.08 by Nov 2003.
#
# Nevertheless, from  2003 to 2010 , It rose from $85 to $125,
# despite falling to $70.77 in Apr 2005.

# %%
GUI(IBM)
