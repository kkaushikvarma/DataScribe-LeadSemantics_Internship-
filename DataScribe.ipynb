# %% [markdown]
# # DataScribe 0.1

# %%
#Dependencies

import matplotlib.pyplot as plt
import numpy as np
import datetime
from math import *
import operator
import statistics
import random

# %%
#Modules

from process_csv import Process_CSV, DataFrame_2D
from grammar import Constructor, parse
from datascribe import GUI
# Out:
# c:\users\kaush\miniconda3\lib\site-packages\matplotlib\__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ### Process CSV

# %%
data = Process_CSV('stocks.csv')
data.labels_row = False
data.set_axis("x",1,'datetime','%b %d %Y')
data.set_axis("y",2,'float', None)
data.variable_col = 0

# %% [markdown]
# ### Data Frame

# %%
data_frame = data.transform()
AAPL = data_frame[0]
AMZN = data_frame[1]
GOOG = data_frame[2]
IBM = data_frame[3]
MSFT = data_frame[4]

def display(frame):
    DataFrame_2D(frame[0],frame[1],None).visualize(True)
    print("\n\n".join(Constructor(DataFrame_2D(frame[0],frame[1],None)).get_string))

# %%
display(GOOG)
# Out:
# GOOG sharply escalated by 576% from  Aug 2004 to Nov 2007 .
# During this period, GOOG escalated slightly to a value of $432.66 by
# Jan 2006, and further continued to increase to a value of $707.0 by
# Oct 2007.
#
# However, from  Nov 2007 to Mar 2010 , there was a marginal
# reduction of 19%. During this period, it decreased to a value of
# $292.96 by Nov 2008 but again escalated back to $619.98 by Dec 2009.

# %%
GUI(GOOG)

# %%
display(AMZN)
# Out:
# With AMZN reaching its minimum value of $5.97 in Sep 2001, AMZN
# unevenly fell from $64 to $38 from  2000 to 2006 .
#
# On the contrary, between  2006 & 2010 , it rose sharply from
# $38 to $128, although it reduced to $42.7 in Nov 2008.

# %%
GUI(AMZN)

# %%
display(IBM)
# Out:
# There was a slight reduction of 15% from  2000 to 2003 .
# During this period, IBM declined to $53.01 by Sep 2002 but increased
# back to a value of $83.08 by Nov 2003.
#
# Nevertheless, there was a significant increase from $85 to $125 from
#  2003 to 2010 , despite declining to $70.77 in Apr 2005.

# %%
GUI(IBM)

# %%
display(AAPL)
# Out:
# During the period,  2000 - 2005 , AAPL slightly increased from
# $25 to $38.
#
# it sharply increased by 480% from  2005 to 2010 . During this
# period, it increased slightly to a value of $91.66 by Nov 2006, and
# further continued to rise to a value of $210.73 by Dec 2009, except
# for a sharp reduction to $85.35 in Dec 2008.

# %%
GUI(AAPL)

# %%
display(MSFT)
# Out:
# Between  2000 & 2003 , there was a marginal fall of 49%.
# During this period, MSFT decreased slightly to $17.65 by Dec 2000, and
# further continued to fall to a value of $17.79 by Sep 2002.
#
# On the contrary, there was a considerable growth from $20 to $28 from
#  2003 to 2010 , despite depleting to $15.81 in Feb 2009.

# %%
GUI(MSFT)
